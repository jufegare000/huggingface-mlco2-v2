# %%
pip install duckdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 734.0 kB/s  0:00:31m0:00:0100:02
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_csv("modelos_co2_enrinchment:limpios.csv", index=False, encoding='utf-8')

# %%
import duckdb

df = duckdb.query("""
    SELECT *
    FROM 'data/raw/hf_snapshots/emissions_v2.parquet'
""").to_df()

print(df)
df.to_csv("modelos_co2_v2.csv", index=False, encoding='utf-8')
# Out:
#                                                model_id author created_at  \
# 0                                      bigscience/bloom   None        NaT
# 1                             kiddyt00/yt-tags-en-zh-v2   None        NaT
# 2                          Enderchef/ICONN-v1-Filmmaker   None        NaT
# 3     sparse-encoder-testing/inference-free-splade-b...   None        NaT
# 4                                 distilbert/distilgpt2   None        NaT
# ...                                                 ...    ...        ...
# 2509                          tomaarsen/qwen3-vl-2b-vdr   None        NaT
# 2510                               osamaeid/test-ssrf-2   None        NaT
# 2511               dodysuss/autotrain-planes-1918465011   None        NaT
# 2512                        MagistrTheOne/veridian-beta   None        NaT
# 2513                         patyns/Ethnicity_Test_v003   None        NaT
#
#      last_modified  downloads  likes            pipeline_tag  \
# ...

# %%
df = duckdb.query("""
    SELECT count(*)
    FROM 'data/raw/hf_snapshots/emissions_v2.parquet'
    where hardware_used is not null and geographical_location is not null
""").to_df()

print(df)
# Out:
#    count_star()
# 0           164

# %%
import duckdb
df = duckdb.query("""
    SELECT *
    FROM 'data/raw/hf_snapshots/emissions_enrichmentv2.parquet'
""").to_df()

print(df)
df.to_csv("modelos_co2_enrinchment_limpios.csv", index=False, encoding='utf-8')
# Out:
#                                                model_id author created_at  \
# 0                                      bigscience/bloom   None        NaT
# 1                             kiddyt00/yt-tags-en-zh-v2   None        NaT
# 2                          Enderchef/ICONN-v1-Filmmaker   None        NaT
# 3     sparse-encoder-testing/inference-free-splade-b...   None        NaT
# 4                                 distilbert/distilgpt2   None        NaT
# ...                                                 ...    ...        ...
# 2509                          tomaarsen/qwen3-vl-2b-vdr   None        NaT
# 2510                               osamaeid/test-ssrf-2   None        NaT
# 2511               dodysuss/autotrain-planes-1918465011   None        NaT
# 2512                        MagistrTheOne/veridian-beta   None        NaT
# 2513                         patyns/Ethnicity_Test_v003   None        NaT
#
#      last_modified  downloads  likes            pipeline_tag  \
# ...
