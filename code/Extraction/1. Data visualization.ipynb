# %%
pip install duckdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 734.0 kB/s  0:00:31m0:00:0100:02
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb

df = duckdb.query("""
    SELECT *
    FROM 'data/raw/hf_snapshots/default_train/0000.parquet'
    LIMIT 10
""").to_df()

print(df)
# Out:
#               publishedAt                                              title  \
# 0 2025-03-04 12:05:25.041   Efficient Test-Time Scaling via Self-Calibration
# 1 2025-03-04 10:47:26.717  Why Are Web AI Agents More Vulnerable Than Sta...
# 2 2025-03-04 08:19:57.557  General Reasoning Requires Learning to Reason ...
# 3 2025-03-04 08:11:33.371  PodAgent: A Comprehensive Framework for Podcas...
# 4 2025-03-04 06:41:49.997  When an LLM is apprehensive about its answers ...
# 5 2025-03-04 05:28:10.012  SampleMix: A Sample-wise Pre-training Data Mix...
# 6 2025-03-04 05:13:44.578  Word Form Matters: LLMs' Semantic Reconstructi...
# 7 2025-03-04 05:12:10.849  Direct Discriminative Optimization: Your Likel...
# 8 2025-03-04 04:56:33.061  From Hours to Minutes: Lossless Acceleration o...
# 9 2025-03-04 04:54:04.054  DiffRhythm: Blazingly Fast and Embarrassingly ...
#
#                                            thumbnail  numComments  \
# ...
